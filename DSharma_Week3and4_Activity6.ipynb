# %%
# Name Dipika Sharma
# DSC 540-T302 Data Preparation
# Week 3 & 4

# Activity 6

# %% [markdown]
# 1. Load the necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Read the adult income dataset from the following URL: https://github.com/TrainingByPackt/Data-Wrangling-with-Python/blob/master/Chapter04/Activity06/.

# %%
df = pd.read_csv("adult_income_data.csv")
df.head()  # head function to show first 5 records
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
# 2  53            Private  234721        11th   7   Married-civ-spouse
# 3  28            Private  338409   Bachelors  13   Married-civ-spouse
# 4  37            Private  284582     Masters  14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family     Male  2174  0  40   United-States  \
# 0     Exec-managerial         Husband     Male     0  0  13   United-States
# 1   Handlers-cleaners   Not-in-family     Male     0  0  40   United-States
# 2   Handlers-cleaners         Husband     Male     0  0  40   United-States
# 3      Prof-specialty            Wife   Female     0  0  40            Cuba
# 4     Exec-managerial            Wife   Female     0  0  40   United-States
#
#     <=50K
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %% [markdown]
# The columns names of adult income dataset does not make sense. some of the columns names are number, which say no information about the data. columns name which are not number also do not make sense. For example columns name like male, United-States.
# Columns Name should always be like that they display the insight of data like instead of male the column name should be gender, or country name intead of United-States.

# %% [markdown]
# 3. Create a script that will read a text file line by line.

# %%
# declaring emplty list to store header name
names = []
with open('adult_income_names.txt','r') as f: # Open text file
    for line in f:
        f.readline()    # Using readline method to read and get the list of all of the lines in file. 
        var=line.split(":")[0]   # split the line at the colon
        names.append(var) # add content to names list.

# %%
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %% [markdown]
# 4. Add a name of Income for the response variable to the dataset.

# %%
# Using append function to add Income column in names list
names.append('Income')

# %%
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'Income']

# %%
df.columns = names # changing the columns name in dataset

# %%
df.head() # Reading the data with assigned column names
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband     Male
# 1             Divorced   Handlers-cleaners   Not-in-family     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# Show a statistical summary of the data set. Did you notice only a small number of columns are included?

# %%
df.describe() # Using describe function to show the summary of statistics

# Yes, I noticed that it is showing the summary of numeric columns and excluding all the character columns
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Many variables in the dataset have multiple factors or classes. Can you write a loop to count and print them?

# %%
vars_class = ['workclass','education','marital-status','occupation','relationship','sex','native-country']

# %%
for v in vars_class:
    classes=df[v].unique()
    num_classes = df[v].nunique()
    print("There are {} classes in the \"{}\" column. They are: {}".format(num_classes,v,classes))
    print("-"*100)
# Out:
# There are 9 classes in the "workclass" column. They are: [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# ----------------------------------------------------------------------------------------------------
# There are 16 classes in the "education" column. They are: [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# ----------------------------------------------------------------------------------------------------
# There are 7 classes in the "marital-status" column. They are: [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 5. Find the missing values.

# %%
# checking the dataframe for null values, below function will count the number of NULL values for each column.
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %% [markdown]
# 6. Create a DataFrame with only age, education, and occupation by using subsetting.

# %%
df_subset = df[['age','education','occupation']]
df_subset.head()
# Out:
#    age   education          occupation
# 0   50   Bachelors     Exec-managerial
# 1   38     HS-grad   Handlers-cleaners
# 2   53        11th   Handlers-cleaners
# 3   28   Bachelors      Prof-specialty
# 4   37     Masters     Exec-managerial

# %% [markdown]
# 7. Plot a histogram of age with a bin size of 20.

# %%
df_subset['age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 8. Create a function to strip the whitespace characters.

# %%
def strip_whitespace(s):
    return s.strip()  # using strip fucntion to remove leading and ending whitespace.

# %%
df_subset.head()
# Out:
#    age   education          occupation
# 0   50   Bachelors     Exec-managerial
# 1   38     HS-grad   Handlers-cleaners
# 2   53        11th   Handlers-cleaners
# 3   28   Bachelors      Prof-specialty
# 4   37     Masters     Exec-managerial

# %% [markdown]
# 9. Use the 'apply' method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column.

# %%
# Occupation column
df_subset['occupation_stripped']=df['occupation'].apply(strip_whitespace)
df_subset['occupation']=df_subset['occupation_stripped']
df_subset.drop(labels=['occupation_stripped'],axis=1,inplace=True)
# Out:
# /var/folders/k0/kqs3mw2j4pl9s5fvm4jvh09h0000gn/T/ipykernel_3924/1871215740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['occupation_stripped']=df['occupation'].apply(strip_whitespace)
# /var/folders/k0/kqs3mw2j4pl9s5fvm4jvh09h0000gn/T/ipykernel_3924/1871215740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['occupation']=df_subset['occupation_stripped']
# ...

# %%
# Education column
df_subset['education_stripped']=df['education'].apply(strip_whitespace)
df_subset['education']=df_subset['education_stripped']
df_subset.drop(labels=['education_stripped'],axis=1,inplace=True)
# Out:
# /var/folders/k0/kqs3mw2j4pl9s5fvm4jvh09h0000gn/T/ipykernel_3924/2267980666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['education_stripped']=df['education'].apply(strip_whitespace)
# /var/folders/k0/kqs3mw2j4pl9s5fvm4jvh09h0000gn/T/ipykernel_3924/2267980666.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['education']=df_subset['education_stripped']

# %% [markdown]
# Answer the following question using conditional filtering/boolean indexing:
#
# "How many black people of age between 30 and 50 (inclusive) are represented in this dataset?"

# %%
df_subset.head()
# Out:
#    age  education         occupation
# 0   50  Bachelors    Exec-managerial
# 1   38    HS-grad  Handlers-cleaners
# 2   53       11th  Handlers-cleaners
# 3   28  Bachelors     Prof-specialty
# 4   37    Masters    Exec-managerial

# %% [markdown]
# 10. Find the number of people who are aged between 30 and 50.

# %%
df_group=df_subset[(df_subset['age']>=30) & (df_subset['age']<=50)]

# %%
df_group.head()
# Out:
#    age  education         occupation
# 0   50  Bachelors    Exec-managerial
# 1   38    HS-grad  Handlers-cleaners
# 4   37    Masters    Exec-managerial
# 5   49        9th      Other-service
# 7   31    Masters     Prof-specialty

# %% [markdown]
# 11. Group the records based on age and education to find how the mean age is distributed.

# %%
df_subset.groupby(['age', 'education']).mean()
# Out:
# /Users/milindkumartandel/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...

# %%
# group by education and see how the mean of age variable is distributed make more sense then the above result where we using the group by on age and education.
df_subset.groupby(['education']).mean()
# Out:
#                     age
# education
# 10th          37.429796
# 11th          32.355745
# 12th          32.000000
# 1st-4th       46.142857
# 5th-6th       42.885886
# 7th-8th       48.445820
# 9th           41.060311
# Assoc-acdm    37.381443
# Assoc-voc     38.553546
# Bachelors     38.904931
# Doctorate     47.702179
# HS-grad       38.974479
# Masters       44.049913
# Preschool     42.764706
# Prof-school   44.746528
# Some-college  35.756275

# %% [markdown]
# 12. Group by occupation and show the summary statistics of age. Find which profession has the oldest workers on average and which profession has its largest share of the workforce above the 75th percentile.

# %%
df_subset.groupby('occupation').describe()['age']
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# ?                  1843.0  40.882800  20.336350  17.0  21.0  35.0  61.0  90.0
# Adm-clerical       3769.0  36.963916  13.364730  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# ...

# %% [markdown]
# Looking at the above data the oldest worker has occupation 'Exec-managerial'. The average of workers age for this occupation is 42.1.
# From above summary we can see that largest share of the workspace above the 75 percentile belongs to 'Priv-hous-serv' which is 57. Also there is unknown occupation '?' which has the largest share of 61.

# %% [markdown]
# 13. Use subset and groupby to find outliers.

# %% [markdown]
# Looking at the summary statitics above we can see that occupation 'Armed-Forces' has only 9 workers which is less number compare to the other occupation workers count. Since this data is too small to be used for analysis purpose so this occupation group is treated as Outliers.

# %%
occupation_Analysis = df_subset.groupby('occupation').describe()['age']

# %%
plt.figure(figsize=(15,8))
plt.barh(y=occupation_Analysis.index,width=occupation_Analysis['count'])
plt.yticks(fontsize=13)
plt.show()

# %% [markdown]
# 14. Merge the data using common keys.

# %% [markdown]
# Practice Merging by common keys: Suppose you are given two datasets where the common key is occupation. Can you merge them?
# First create two such disjoint datasets by taking random samples from the full dataset and then try merging. Include at least 2 other columns along with the common key column for each dataset.
# Notice how the resulting dataset, after merging, may have more data points than either of the two starting datasets if your common key is not unique? Why is it so?

# %%
# Let consider the first dataset has 'age', 'workclass' and 'occupation' as column

df_set1 = df[['age','workclass','occupation']].sample(5,random_state=101)

# %%
df_set1.head()
# Out:
#        age   workclass          occupation
# 22356   51     Private   Machine-op-inspct
# 26008   19     Private               Sales
# 20733   40     Private     Exec-managerial
# 14475   45   State-gov     Exec-managerial
# 27907   61     Private        Craft-repair

# %%
# Second dataset have columns education and ocuupation

df_set2 = df[['education','occupation']].sample(5,random_state=101)

# %%
df_set2.head()
# Out:
#         education          occupation
# 22356     HS-grad   Machine-op-inspct
# 26008        11th               Sales
# 20733     HS-grad     Exec-managerial
# 14475   Bachelors     Exec-managerial
# 27907     7th-8th        Craft-repair

# %%
# using merge method to merged dataset 1 and dataset 2

df_merged = pd.merge(df_set1,df_set2,on='occupation',how='inner').drop_duplicates()

# %%
df_merged
# Out:
#    age   workclass          occupation   education
# 0   51     Private   Machine-op-inspct     HS-grad
# 1   19     Private               Sales        11th
# 2   40     Private     Exec-managerial     HS-grad
# 3   40     Private     Exec-managerial   Bachelors
# 4   45   State-gov     Exec-managerial     HS-grad
# 5   45   State-gov     Exec-managerial   Bachelors
# 6   61     Private        Craft-repair     7th-8th

# %% [markdown]
# Looking at the above merged data we can see since we use the occupation for joining the dataset 1 and dataset 2 and we do not have all unique value for occupation in both datasets that is why some of the values is getting multiply and we gettig two of them in merged dataset. For example we have ocuupation 'Exec-managerial' in dataset 1 with two separate workclass and same occupation is present in dataset 2 with two different eductaion. As a result in merged dataset we will get 4 rows with same occupation with 2 workclass and 2 separate eductaion. It is always recommended to use primary or foreign key which is interger when we want to join the multiple dataset.
